# %% [markdown]
# <a href="https://colab.research.google.com/github/bidulgiya999/DataScience2024/blob/main/(%ED%99%A9%EC%8A%B9%EC%9E%AC)%ED%83%9C%EC%96%91%EA%B4%91%EB%B0%9C%EC%A0%84%EC%86%8C%EC%9C%84%EC%B9%98_%EC%8B%9C%EA%B0%81%ED%99%94%ED%95%98%EA%B8%B0_%EC%B2%98%EC%9D%8C%EB%B6%80%ED%84%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 구글 드라이브 마운트는 항상 먼저하기

# %%
# 한글 폰트 설치
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# 실행수 세션 다시시작
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 2s (6,213 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
import folium
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# matplotlib 나눔바른고딕체로 폰츠 폰트 설정, 세션 다시시작후 폰트 다시 실행
plt.rc('font', family='NanumBarunGothic')

# %%
csvPath = "/content/drive/MyDrive/DataScience/제주특별자치도_태양광발전소현황.csv"

# %%
df=pd.read_csv(csvPath,encoding="cp949")
df.head()
# Out:
#    행정시  읍면동        허가일자            상호  설비용량(KW)    상태       사업개시일     데이터기준일자
# 0  제주시  구좌읍  1998-06-10  행원풍력발전단지(1차)    3480.0  사업개시  2000-04-05  2022-06-30
# 1  제주시  회천동  2002-12-09     파낙스에너지(주)    1000.0  사업개시  2002-12-18  2022-06-30
# 2  제주시  한경면  2003-04-14      한경풍력 1단계    6000.0  사업개시  2004-02-28  2022-06-30
# 3  제주시  한경면  2005-04-04      신창풍력발전단지    1700.0  사업개시  2006-03-03  2022-06-30
# 4  제주시  구좌읍  2005-08-30     제주월정풍력발전소    1500.0  사업개시  2006-07-20  2022-06-30

# %%
df.tail()
# Out:
#        행정시  읍면동        허가일자           상호  설비용량(KW)   상태 사업개시일     데이터기준일자
# 2143   제주시  한경면  2022-06-08    민재 태양광발전소      99.6  인허가   NaN  2022-06-30
# 2144   제주시  한림읍  2022-06-08  효일4호 태양광발전소      99.0  인허가   NaN  2022-06-30
# 2145   제주시  한림읍  2022-06-08  효일3호 태양광발전소      99.0  인허가   NaN  2022-06-30
# 2146   제주시  한림읍  2022-06-08  효일5호 태양광발전소      99.0  인허가   NaN  2022-06-30
# 2147  서귀포시  성산읍  2022-06-21   한라2호소수력발전소     210.0  인허가   NaN  2022-06-30

# %%
df.isna().sum()
# Out:
# 행정시           0
# 읍면동           0
# 허가일자          0
# 상호            0
# 설비용량(KW)      0
# 상태            0
# 사업개시일       577
# 데이터기준일자       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2148 entries, 0 to 2147
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   행정시       2148 non-null   object
#  1   읍면동       2148 non-null   object
#  2   허가일자      2148 non-null   object
#  3   상호        2148 non-null   object
#  4   설비용량(KW)  2148 non-null   float64
#  5   상태        2148 non-null   object
#  6   사업개시일     1571 non-null   object
#  7   데이터기준일자   2148 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 134.4+ KB

# %%
df.value_counts()
# Out:
# 행정시   읍면동  허가일자        상호                   설비용량(KW)  상태    사업개시일       데이터기준일자
# 서귀포시  안덕면  2007-12-14  번내태양광발전주식회사          90.72     사업개시  2008-05-13  2022-06-30    2
#       강정동  2014-12-09  (유)용흥마을태양광발전소        99.00     사업개시  2015-10-29  2022-06-30    1
# 제주시   조천읍  2017-09-30  제주감귤167호 태양광발전소      633.36    사업개시  2019-07-17  2022-06-30    1
#            2018-02-13  대흘4호 태양광발전소          99.63     사업개시  2020-01-22  2022-06-30    1
#                        대흘3호 태양광발전소          99.63     사업개시  2019-11-04  2022-06-30    1
#                                                                                      ..
# 서귀포시  안덕면  2018-06-21  동선 태양광발전소            99.36     사업개시  2019-02-08  2022-06-30    1
#            2018-06-12  태양6호 태양광발전소          498.42    사업개시  2020-10-21  2022-06-30    1
#            2018-05-31  안덕한빛나눔에너지 태양광발전소 1호  992.80    사업개시  2019-12-31  2022-06-30    1
#            2018-05-18  (주)모록밭 태양광발전소        492.48    사업개시  2020-09-10  2022-06-30    1
# ...

# %%
# 결측치가 있는 행은 삭제
df.dropna(axis=0,inplace=True)
df.isna().sum()
# Out:
# 행정시         0
# 읍면동         0
# 허가일자        0
# 상호          0
# 설비용량(KW)    0
# 상태          0
# 사업개시일       0
# 데이터기준일자     0
# dtype: int64

# %%
df.head(10)
# Out:
#     행정시  읍면동        허가일자            상호  설비용량(KW)    상태       사업개시일     데이터기준일자
# 0   제주시  구좌읍  1998-06-10  행원풍력발전단지(1차)   3480.00  사업개시  2000-04-05  2022-06-30
# 1   제주시  회천동  2002-12-09     파낙스에너지(주)   1000.00  사업개시  2002-12-18  2022-06-30
# 2   제주시  한경면  2003-04-14      한경풍력 1단계   6000.00  사업개시  2004-02-28  2022-06-30
# 3   제주시  한경면  2005-04-04      신창풍력발전단지   1700.00  사업개시  2006-03-03  2022-06-30
# 4   제주시  구좌읍  2005-08-30     제주월정풍력발전소   1500.00  사업개시  2006-07-20  2022-06-30
# 5   제주시  한경면  2006-03-03          오복산전     59.87  사업개시  2006-07-11  2022-06-30
# 6   제주시  한경면  2006-08-11     탐라해상풍력발전소  30000.00  공사진행  2017-09-16  2022-06-30
# 7   제주시  한경면  2006-08-24       오복산전 3호     29.52  사업개시  2006-09-25  2022-06-30
# 8   제주시  조천읍  2007-01-05        민솔라에너지     90.72  사업개시  2007-04-04  2022-06-30
# 9  서귀포시  성산읍  2007-02-21    제주에너지 주식회사    200.00  사업개시  2008-09-29  2022-06-30

# %%
# 사업개시가 아닌것
df[df["상태"]!="사업개시"]
# Out:
#       행정시  읍면동        허가일자         상호  설비용량(KW)    상태       사업개시일     데이터기준일자
# 6     제주시  한경면  2006-08-11  탐라해상풍력발전소   30000.0  공사진행  2017-09-16  2022-06-30
# 29   서귀포시  성산읍  2008-02-28   성산풍력 1단계   12000.0  공사진행  2009-03-30  2022-06-30
# 583   제주시  한경면  2016-11-16     성용유화발전     750.0   인허가  2016-11-16  2022-06-30

# %%
# df에서 상태가 사업개시가 아닌것들만 인덱스값만 받아오기
editList=df[df["상태"]!="사업개시"].index
editList
# Out:
# Index([6, 29, 583], dtype='int64')

# %%
for index in editList:
    df.loc[index,"상태"] == "사업개시"

# %%
# 다른 데이터
csv = "/content/drive/MyDrive/DataScience/제주특별자치도_신재생에너지발전시설현황.csv"
df = pd.read_csv(csv,encoding="cp949")
df
# Out:
#             허가일자                      상호  설비용량(KW)              설치장소  원동력종류  \
# 0     2019-05-22               북촌서모풍력발전소    3000.0   제주특별자치도 제주시 조천읍     풍력
# 1     2016-12-12              동복리마을풍력발전소    2000.0   제주특별자치도 제주시 구좌읍     풍력
# 2     2016-10-17                 수망풍력발전소   25200.0  제주특별자치도 서귀포시 남원읍     풍력
# 3     2014-06-13              동복북촌풍력발전단지   30000.0   제주특별자치도 제주시 구좌읍     풍력
# 4     2014-05-02                 상명풍력발전소   21000.0   제주특별자치도 제주시 한림읍     풍력
# ...          ...                     ...       ...               ...    ...
# 1577  2013-03-12                 주식회사 이웰    2950.0  제주특별자치도 서귀포시 토평동  바이오가스
# 1578  2012-11-27     농업회사법인 주식회사 한라산 바이오     500.0  제주특별자치도 서귀포시 안덕면  바이오가스
# 1579  2010-06-21  (주)농업회사법인 제주축산바이오가스발전소      99.0   제주특별자치도 제주시 한림읍  바이오가스
# 1580  2002-12-09               파낙스에너지(주)    1000.0   제주특별자치도 제주시 회천동  바이오가스
# 1581  2015-05-27          서광산업 신재생에너지발전소    2400.0   제주특별자치도 제주시 애월읍     기타
#
#            사업개시일     데이터기준일자
# ...

# %%
df.isna().sum()
# Out:
# 허가일자        0
# 상호          0
# 설비용량(KW)    0
# 설치장소        0
# 원동력종류       0
# 사업개시일       0
# 데이터기준일자     0
# dtype: int64

# %%
df.head()
# Out:
#          허가일자          상호  설비용량(KW)              설치장소 원동력종류       사업개시일  \
# 0  2019-05-22   북촌서모풍력발전소    3000.0   제주특별자치도 제주시 조천읍    풍력  2020-07-31
# 1  2016-12-12  동복리마을풍력발전소    2000.0   제주특별자치도 제주시 구좌읍    풍력  2017-12-01
# 2  2016-10-17     수망풍력발전소   25200.0  제주특별자치도 서귀포시 남원읍    풍력  2020-06-29
# 3  2014-06-13  동복북촌풍력발전단지   30000.0   제주특별자치도 제주시 구좌읍    풍력  2015-08-01
# 4  2014-05-02     상명풍력발전소   21000.0   제주특별자치도 제주시 한림읍    풍력  2016-08-22
#
#       데이터기준일자
# 0  2022-11-16
# 1  2022-11-16
# 2  2022-11-16
# 3  2022-11-16
# 4  2022-11-16

# %%
df.tail()
# Out:
#             허가일자                      상호  설비용량(KW)              설치장소  원동력종류  \
# 1577  2013-03-12                 주식회사 이웰    2950.0  제주특별자치도 서귀포시 토평동  바이오가스
# 1578  2012-11-27     농업회사법인 주식회사 한라산 바이오     500.0  제주특별자치도 서귀포시 안덕면  바이오가스
# 1579  2010-06-21  (주)농업회사법인 제주축산바이오가스발전소      99.0   제주특별자치도 제주시 한림읍  바이오가스
# 1580  2002-12-09               파낙스에너지(주)    1000.0   제주특별자치도 제주시 회천동  바이오가스
# 1581  2015-05-27          서광산업 신재생에너지발전소    2400.0   제주특별자치도 제주시 애월읍     기타
#
#            사업개시일     데이터기준일자
# 1577  2015-07-21  2022-11-16
# 1578  2015-05-01  2022-11-16
# 1579  2010-08-24  2022-11-16
# 1580  2002-12-18  2022-11-16
# 1581  2015-12-17  2022-11-16

# %%
df["원동력종류"].unique()
# Out:
# array(['풍력', '태양광', '수력', '바이오가스', '기타'], dtype=object)

# %%
# 태양광이 몇개인지 확인하는 방법들

# %%
df[df["원동력종류"]=="태양광"].value_counts().sum()
# Out:
# 1547

# %%
len(df[df["원동력종류"]=="태양광"])
# Out:
# 1547

# %%
df2 = df[df["원동력종류"]=="태양광"]
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1547 entries, 24 to 1570
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   허가일자      1547 non-null   object
#  1   상호        1547 non-null   object
#  2   설비용량(KW)  1547 non-null   float64
#  3   설치장소      1547 non-null   object
#  4   원동력종류     1547 non-null   object
#  5   사업개시일     1547 non-null   object
#  6   데이터기준일자   1547 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 96.7+ KB

# %%
len(df[df["원동력종류"]=="바이오가스"])
# Out:
# 5

# %%
len(df[df["원동력종류"]=="풍력"])
# Out:
# 24

# %%
len(df[df["원동력종류"]=="수력"])
# Out:
# 5

# %%
# 설비용량 총량계산
df2.columns
# Out:
# Index(['허가일자', '상호', '설비용량(KW)', '설치장소', '원동력종류', '사업개시일', '데이터기준일자'], dtype='object')

# %%
df2.rename({"설비용량(KW)":"설비용량"},axis=1,inplace=True)
df2.설비용량.sum()
# Out:
# <ipython-input-62-9e987d1dcc37>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.rename({"설비용량(KW)":"설비용량"},axis=1,inplace=True)
# 509086.72

# %%
print(df2["설치장소"].unique())
print(df2["설치장소"].nunique())
# Out:
# ['제주특별자치도 제주시 구좌읍' '제주특별자치도 서귀포시 안덕면' '제주특별자치도 서귀포시 표선면'
#  '제주특별자치도 서귀포시 성산읍' '제주특별자치도 서귀포시 법환동' '제주특별자치도 서귀포시 대정읍'
#  '제주특별자치도 제주시 한림읍' '제주특별자치도 서귀포시 남원읍' '제주특별자치도 서귀포시 상예동'
#  '제주특별자치도 서귀포시 회수동' '제주특별자치도 제주시 조천읍' '제주특별자치도 제주시 도남동' '제주특별자치도 제주시 애월읍'
#  '제주특별자치도 서귀포시 토평동' '제주특별자치도 서귀포시 강정동' '제주특별자치도 서귀포시 중문동'
#  '제주특별자치도 제주시 봉개동' '제주특별자치도 서귀포시 월평동' '제주특별자치도 제주시 용담이동'
#  '제주특별자치도 제주시 일도이동' '제주특별자치도 제주시 회천동' '제주특별자치도 제주시 해안동' '제주특별자치도 서귀포시 호근동'
#  '제주특별자치도 제주시 오라삼동' '제주특별자치도 제주시 한경면' '제주특별자치도 제주시 아라이동'
#  '제주특별자치도 제주시 오라이동' '제주특별자치도 제주시 용강동' '제주특별자치도 제주시 외도일동'
#  '제주특별자치도 제주시 삼양일동' '제주특별자치도 서귀포시 도순동' '제주특별자치도 서귀포시 상효동'
#  '제주특별자치도 서귀포시 서홍동' '제주특별자치도 제주시 이도일동' '제주특별자치도 제주시 오등동'
#  '제주특별자치도 서귀포시 서호동' '제주특별자치도 제주시 영평동' '제주특별자치도 서귀포시 동홍동'
#  '제주특별자치도 서귀포시 하원동' '제주특별자치도 제주시 이호이동' '제주특별자치도 제주시 화북이동'
#  '제주특별자치도 서귀포시 색달동' '제주특별자치도 서귀포시 서귀동' '제주특별자치도 제주시 도련이동'
#  '제주특별자치도 제주시 오라일동' '제주특별자치도 서귀포시 하효동' '제주특별자치도 제주시 도평동'
#  '제주특별자치도 서귀포시 하예동' '제주특별자치도 제주시 노형동' '제주특별자치도 제주시 삼도이동'
# ...

# %%
# 태양광 발전소가 1년간 새로 사업을 시작한 갯수, 발전용량 확인
(df2["사업개시일"]>="2021-01-01")&(df2["사업개시일"]<="2021-12-31")
# Out:
# 24      False
# 25       True
# 26      False
# 27      False
# 28      False
#         ...
# 1566    False
# 1567    False
# 1568    False
# 1569    False
# 1570    False
# Name: 사업개시일, Length: 1547, dtype: bool

# %%
# 태양광 발전소가 1년간 새로 사업을 시작한 갯수, 발전용량 확인
df_year21=df2[(df2["사업개시일"]>="2021-01-01")&(df2["사업개시일"]<="2021-12-31")]
df_year21.head()
# Out:
#           허가일자           상호    설비용량              설치장소 원동력종류       사업개시일  \
# 25  2021-08-03   태양7호태양광발전소  198.88  제주특별자치도 서귀포시 안덕면   태양광  2021-12-10
# 33  2021-03-02    못거리태양광발전소   19.80  제주특별자치도 서귀포시 법환동   태양광  2021-09-16
# 34  2021-03-02  도원2호 태양광발전소  346.08  제주특별자치도 서귀포시 대정읍   태양광  2021-07-12
# 35  2021-03-22   건희2 태양광발전소   59.04   제주특별자치도 제주시 한림읍   태양광  2021-07-29
# 36  2021-02-08       펠롱 발전소   99.19  제주특별자치도 서귀포시 안덕면   태양광  2021-11-01
#
#        데이터기준일자
# 25  2022-11-16
# 33  2022-11-16
# 34  2022-11-16
# 35  2022-11-16
# 36  2022-11-16

# %%
df_year21["설비용량"].sum()
# Out:
# 108352.51999999999

# %%
df2["설비용량"].sum()
# Out:
# 509086.72

# %%
# 지도 시작화
# geopy
# 주소값을 위, 경도로 변환
#!pip list
# !pip install geopy

# %%
import geopy

# %%
# 가입 없이 주소->좌표 변환
from geopy.geocoders import Nominatim

# 주소나 위도, 경도가 중복되지 않은 고유한 정보를
# 리스트에 각각 담아주기 위해 빈 리스트 생성
unique_addr=[]
unique_lat=[]
unique_lng=[]
except_addr=[]

# 주소를 위도와 경도로 변환해 주는 함수
def geocoding(address):
    geolocoder = Nominatim(user_agent = 'South Korea', timeout=None)
    geo = geolocoder.geocode(address)
    # 주소값을 제대로 인식하지 못할때
    # 위도와 경도값을 None값을 리턴한다.
    if geo==None:
        print('주소가 어디인지 인식할 수 없습니다.')
        except_addr.append(address)
        return 0, 0
    else:
        return geo.latitude, geo.longitude

# %%
geocoding("Seoul")
# Out:
# (37.5666791, 126.9782914)

# %%
geocoding("평택")
# Out:
# (36.9908233, 127.0853183)

# %%
geo=geocoding("제주특별자치도 서귀포시 안덕면")
print(geo)
# Out:
# (33.27688, 126.34925)

# %%
df2.columns
# Out:
# Index(['허가일자', '상호', '설비용량', '설치장소', '원동력종류', '사업개시일', '데이터기준일자'], dtype='object')

# %%
# 데이터프레임 [설치장소][경도][위도]
# 중복된 주소제거
mapAddr_df=df2["설치장소"].unique()
mapAddr_df["설치장소"] == "제주특별자치도 제주시 삼도이동"
# Out:
# array(['제주특별자치도 제주시 구좌읍', '제주특별자치도 서귀포시 안덕면', '제주특별자치도 서귀포시 표선면',
#        '제주특별자치도 서귀포시 성산읍', '제주특별자치도 서귀포시 법환동', '제주특별자치도 서귀포시 대정읍',
#        '제주특별자치도 제주시 한림읍', '제주특별자치도 서귀포시 남원읍', '제주특별자치도 서귀포시 상예동',
#        '제주특별자치도 서귀포시 회수동', '제주특별자치도 제주시 조천읍', '제주특별자치도 제주시 도남동',
#        '제주특별자치도 제주시 애월읍', '제주특별자치도 서귀포시 토평동', '제주특별자치도 서귀포시 강정동',
#        '제주특별자치도 서귀포시 중문동', '제주특별자치도 제주시 봉개동', '제주특별자치도 서귀포시 월평동',
#        '제주특별자치도 제주시 용담이동', '제주특별자치도 제주시 일도이동', '제주특별자치도 제주시 회천동',
#        '제주특별자치도 제주시 해안동', '제주특별자치도 서귀포시 호근동', '제주특별자치도 제주시 오라삼동',
#        '제주특별자치도 제주시 한경면', '제주특별자치도 제주시 아라이동', '제주특별자치도 제주시 오라이동',
#        '제주특별자치도 제주시 용강동', '제주특별자치도 제주시 외도일동', '제주특별자치도 제주시 삼양일동',
#        '제주특별자치도 서귀포시 도순동', '제주특별자치도 서귀포시 상효동', '제주특별자치도 서귀포시 서홍동',
#        '제주특별자치도 제주시 이도일동', '제주특별자치도 제주시 오등동', '제주특별자치도 서귀포시 서호동',
#        '제주특별자치도 제주시 영평동', '제주특별자치도 서귀포시 동홍동', '제주특별자치도 서귀포시 하원동',
#        '제주특별자치도 제주시 이호이동', '제주특별자치도 제주시 화북이동', '제주특별자치도 서귀포시 색달동',
# ...

# %%
unique_lat=[]
unique_lng=[]

for addr in mapAddr_df:
    if addr=="제주특별자치도 제주시 삼도이동":
        addr = "제주시 삼도 2동"
    #print(addr)
    geo = geocoding(addr)
    print(geo)
    unique_lat.append(geo[0])
    unique_lng.append(geo[1])
# Out:
# (33.51662, 126.81055)
# (33.27688, 126.34925)
# (33.3504543, 126.794049)
# (33.41805, 126.88147)
# (33.24113, 126.51285)
# (33.2218157, 126.2529945)
# (33.39344, 126.26684)
# (33.3076683, 126.6907475)
# (33.26177, 126.38678)
# (33.26549, 126.44363)
# (33.50888, 126.66305)
# (33.4905148, 126.5239964)
# (33.45079, 126.3752)
# (33.2705286, 126.5841149)
# (33.24695, 126.48927)
# (33.262002, 126.4288617)
# (33.484188, 126.5993497)
# (33.24501, 126.46294)
# (33.50742, 126.50615)
# (33.50864, 126.53795)
# (33.4956, 126.61479)
# (33.44899, 126.46036)
# (33.25632, 126.53351)
# (33.49487, 126.50508)
# (33.3305, 126.21066)
# (33.48148, 126.55055)
# (33.47081, 126.50991)
# (33.47017, 126.58934)
# (33.4855847, 126.4284514)
# (33.52345, 126.599)
# (33.2569662, 126.4731036)
# (33.2896254, 126.5945088)
# (33.25965, 126.55175)
# (33.5059, 126.5278)
# (33.46148, 126.53087)
# (33.25759, 126.51916)
# (33.4812, 126.57106)
# (33.26184, 126.56804)
# (33.2626587, 126.4600239)
# (33.498551, 126.4565213)
# ...

# %%
map_df = pd.DataFrame({'설치장소':df2['설치장소'].unique(),
                       '위도':unique_lat,
                       '경도':unique_lng})

# %%
len(df2['설치장소'].unique()), len(unique_lat), len(unique_lng)
# Out:
# (52, 52, 52)

# %%
map_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   설치장소    52 non-null     object
#  1   위도      52 non-null     float64
#  2   경도      52 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB

# %%
# map_df["설치장소"]를 인덱스로 표현
map_df.set_index("설치장소",inplace=True)

# %%
map_df.head()
# Out:
#                          위도          경도
# 설치장소
# 제주특별자치도 제주시 구좌읍   33.516620  126.810550
# 제주특별자치도 서귀포시 안덕면  33.276880  126.349250
# 제주특별자치도 서귀포시 표선면  33.350454  126.794049
# 제주특별자치도 서귀포시 성산읍  33.418050  126.881470
# 제주특별자치도 서귀포시 법환동  33.241130  126.512850

# %%
import pandas as pd
import folium

# 지도가 그려질 중심 좌표(대략 제주도의 중심 좌표), 지도를 그릴때 얼마나 줌을 적용할지
jeju_map = folium.Map(location=[33.38, 126.55], zoom_start=11)

for i in range(len(map_df)):
    pos_list = [map_df.iloc[i][0], map_df.iloc[i][1]]
    folium.Marker([map_df.iloc[i][0], map_df.iloc[i][1]], popup=map_df.index[i]).add_to(jeju_map)

jeju_map.save('jeju.html')
# Out:
# <ipython-input-141-848cf13f6487>:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pos_list = [map_df.iloc[i][0], map_df.iloc[i][1]]
# <ipython-input-141-848cf13f6487>:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   folium.Marker([map_df.iloc[i][0], map_df.iloc[i][1]], popup=map_df.index[i]).add_to(jeju_map)
